# %% [markdown]
# ## Tuple
# Immutable list
# () is used
# A tuple is an immutable list of values. Tuples are one of Python's simplest and most common collection types, and
# can be created with the comma operator (value = 1, 2, 3).

# %%
l=list()#[]
t=tuple()#()

# %%
data1=[1,2,3,"python",[3,3,0]]
data=(10,20,'ram',56.8,(10,20,30),[1,2,3])

# %%
data
# Out:
# (10, 20, 'ram', 56.8, (10, 20, 30), [1, 2, 3])

# %%
type(data)
# Out:
# tuple

# %%
len(data)
# Out:
# 6

# %% [markdown]
# This process is called tuple packing because the objects being assigned are “packed” into a single immutable tuple object.

# %%
x='a','mahesh',10.56

# %%
type(x)
# Out:
# tuple

# %%
t2='a',
# t2=tuple()
type(t2)
# Out:
# tuple

# %% [markdown]
# ### Tuples are immutable
# One of the main differences between lists and tuples in Python is that tuples are immutable, that is, one cannot
# add or modify items once the tuple is initialized. For example:

# %%
tupl3=1,'mahesh',10.56,(10,20,30)

# %%
tupl3
# Out:
# (1, 'mahesh', 10.56, (10, 20, 30))

# %%
tupl3[2]="python"
tupl3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-13687974c9a4> in <cell line: 0>()
# ----> 1 tupl3[2]="python"
#       2 tupl3
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupl3=(1,'mahesh',10.56,[10,20,30])
print(tupl3[3])
print(tupl3[3][0])
tupl3[3][0]=100
tupl3
# Out:
# [10, 20, 30]
# 10
# (1, 'mahesh', 10.56, [100, 20, 30])

# %%
help(tupl3.index)
# Out:
# Help on built-in function index:
#
# index(value, start=0, stop=9223372036854775807, /) method of builtins.tuple instance
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
tupl3.index(10.56)
# Out:
# 2

# %%
tupl3
# Out:
# (1, 'mahesh', 10.56, (10, 20, 30))

# %%
l=(1,230,0,"python")
l[3][0]="q"
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-4370bfc62e79> in <module>
#       1 l=(1,230,0,"python")
# ----> 2 l[3][0]="q"
#       3 l
#
# TypeError: 'str' object does not support item assignment

# %%
a = tupl3[1]
print(tupl3)
a.endswith('h')
b = a = tupl3[1] + "kiran"
b
print(tupl3)
print(id(tupl3))
tupl3[1] = 'maheshkiran'
tupl3
# Out:
# (1, 'maheshkiran', 10.56, (10, 20, 30))
# (1, 'maheshkiran', 10.56, (10, 20, 30))
# 132963510582416
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-917190122.py in <cell line: 0>()
#       6 print(tupl3)
#       7 print(id(tupl3))
# ----> 8 tupl3[1] = 'maheshkiran'
#       9 tupl3
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupl3 = (1, 'maheshkiran', 10.56, (10, 20, 30))
print(id(tupl3))
tupl3
# Out:
# 132963510816576
# (1, 'maheshkiran', 10.56, (10, 20, 30))

# %%
l=[1,2,3,"python"]
l[3]="Java"
l
# Out:
# [1, 2, 3, 'Java']

# %%
tuple1=(1,2,3,4)
tuple1[0]
# Out:
# 1

# %%
tuple1[0:2]
# Out:
# (1, 2)

# %% [raw]
# #       +
# #---------------
# # int   | int
# # float |float
# # int   |float
# # float |int
# # String|String
# # tuple |tuple

# %%
tuple2=(1,3,444,55)
tup=tuple2 + (2,777,"string")
print(tup)
# Out:
# (1, 3, 444, 55, 2, 777, 'string')

# %%
tuple2  =tuple2[0:3]
tuple2
# Out:
# (1, 3, 444)

# %%
'python'*'java'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-b55e1dbebc16> in <module>
# ----> 1 'python'*'java'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'python '*2
# Out:
# 'python python '

# %%
tuple2=(1,3,444,55)

# %%
tuple2 * 2
# Out:
# (1, 3, 444, 55, 1, 3, 444, 55)

# %%
data=(10,20,'rahul',40.6,'z')
data1=data
del data
print('Data1',  data1)
print (data)
# Out:
# Data1 (10, 20, 'rahul', 40.6, 'z')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b86996f0a130> in <cell line: 0>()
#       3 del data
#       4 print('Data1',  data1)
# ----> 5 print (data)
#
# NameError: name 'data' is not defined

# %%
print(data1)
# Out:
# (10, 20, 'rahul', 40.6, 'z')

# %%
data = ("ab","bc", "de")
max(data)
# Out:
# 'de'

# %%
data=(10,20,40.6)
min(data)
# Out:
# 10

# %%
max(data)
# Out:
# 40.6

# %%
data=(10,20,40.6,"a")

# %%
data=(10,20,40.6,"10")
min(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3820921877.py in <cell line: 0>()
#       1 data=(10,20,40.6,"10")
# ----> 2 min(data)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# no <capital letter <small letter
data=("20","2","abcd")
# data=(10,2)
min(data)
# Out:
# '2'

# %%
data=("20","2","abcd","kiran",'iuu')
rev=data[::-1]

# rev=data[::-3]
rev
# Out:
# ('iuu', 'kiran', 'abcd', '2', '20')

# %%
list1=['a',1,100,233]
t=tuple(list1)
print (t)
print(type(t))
# Out:
# ('a', 1, 100, 233)
# <class 'tuple'>

# %%
lt=[]
lt=list(t)
print(type(lt))
print (list(t))
# Out:
# <class 'list'>
# ['a', 1, 100, 233]

# %%
len(t)

# %% [markdown]
# # Why use a tuple instead of a list?
#
# Program execution is faster when manipulating a tuple than it is for the equivalent list. (This is probably not going to be noticeable when the list or tuple is small.)
#
# Sometimes you don’t want data to be modified. If the values in the collection are meant to remain constant for the life of the program, using a tuple instead of a list guards against accidental modification.
#
# There is another Python data type that you will encounter shortly called a dictionary, which requires as one of its components a value that is of an immutable type. A tuple can be used for this purpose, whereas a list can’t be.

# %% [markdown]
# - Tuples are stored in a single block of memory. Tuples are immutable so, It doesn't require extra space to store new objects.
# - Lists are allocated in two blocks: the fixed one with all the Python object information and a variable sized block for the data.
# - It is the reason creating a tuple is faster than List.
# - It also explains the slight difference in indexing speed is faster than lists, because in tuples for indexing it follows fewer pointers
